# %% [markdown]
# <a href="https://colab.research.google.com/github/GrCOTE7/deep_learning_course/blob/main/01-01%20Introduction%20au%20Deep%20Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Intro au Deep Learning (By Kevin Degila)
#
# Ce code correspond à la vidéo #7 d'une [série de 160 épisodes](https://www.youtube.com/watch?v=XXyMPp_IwXg&list=PL049bGjkT7dIARLPrxvA4-tbEcg6k0UDX&index=7)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD

# %%
import pandas as pd
import numpy as np

data_url = "http://lib.stat.cmu.edu/datasets/boston"
raw_df = pd.read_csv(data_url, sep=r"\s+", skiprows=22, header=None)
data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
target = raw_df.values[1::2, 2]

# Scaling the data
from sklearn.preprocessing import StandardScaler
s = StandardScaler()
data = s.fit_transform(data)
target = target.reshape((-1, 1))

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.3, random_state=80718)

# %%
data.shape
# Out:
# (506, 13)

# %%
lr = Sequential([Dense(units=1, activation='relu')])
lr.compile(optimizer=SGD(learning_rate=0.1), loss='mse')
history = lr.fit(X_train, y_train, epochs=50, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 368.8022 - val_loss: 110.6600
# Epoch 2/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 101.9991 - val_loss: 102.3785
# Epoch 3/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 89.5202 - val_loss: 85.2171
# Epoch 4/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 63.3431 - val_loss: 46.9881
# Epoch 5/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 35.6361 - val_loss: 94.0246
# Epoch 6/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 49.7162 - val_loss: 26.6336
# Epoch 7/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 28.4241 - val_loss: 25.6569
# Epoch 8/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 26.1659 - val_loss: 24.1348
# Epoch 9/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 23.2564 - val_loss: 26.6521
# Epoch 10/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 22.7426 - val_loss: 33.5819
# Epoch 11/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 25.6664 - val_loss: 26.0315
# Epoch 12/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 21.2420 - val_loss: 29.3335
# Epoch 13/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 24.9426 - val_loss: 25.3099
# Epoch 14/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 21.7964 - val_loss: 31.3097
# Epoch 15/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 21.3166 - val_loss: 30.8805
# Epoch 16/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 24.9602 - val_loss: 40.5608
# Epoch 17/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 34.1696 - val_loss: 30.5110
# Epoch 18/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 31.3048 - val_loss: 29.4994
# Epoch 19/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 24.0127 - val_loss: 63.5974
# Epoch 20/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 32.5733 - val_loss: 28.3386
# Epoch 21/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 25.3305 - val_loss: 86.6385
# Epoch 22/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 45.6676 - val_loss: 46.9654
# Epoch 23/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 24.0656 - val_loss: 34.0234
# Epoch 24/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 27.6794 - val_loss: 26.5157
# Epoch 25/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 22.1317 - val_loss: 24.1058
# Epoch 26/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 22.2363 - val_loss: 48.9150
# Epoch 27/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 31.4960 - val_loss: 25.1244
# Epoch 28/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 19.3862 - val_loss: 25.9280
# Epoch 29/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 20.5090 - val_loss: 343.5678
# Epoch 30/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 114.8534 - val_loss: 29.7585
# Epoch 31/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 28.8666 - val_loss: 30.4046
# Epoch 32/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 24.2635 - val_loss: 25.0692
# Epoch 33/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 20.6151 - val_loss: 30.0883
# Epoch 34/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 21.6056 - val_loss: 58.8273
# Epoch 35/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 38.8192 - val_loss: 26.4417
# Epoch 36/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 24.8671 - val_loss: 31.7594
# Epoch 37/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 20.5278 - val_loss: 33.0173
# Epoch 38/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 25.3064 - val_loss: 26.9417
# Epoch 39/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 21.2391 - val_loss: 61.8398
# Epoch 40/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 24.7723 - val_loss: 58.6581
# Epoch 41/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 27.7792 - val_loss: 39.2274
# Epoch 42/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 25.4010 - val_loss: 24.2655
# Epoch 43/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 22.2127 - val_loss: 36.5545
# Epoch 44/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 25.8060 - val_loss: 44.4727
# Epoch 45/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 30.1527 - val_loss: 80.8482
# Epoch 46/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 33.4866 - val_loss: 41.2113
# Epoch 47/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 24.4509 - val_loss: 27.7582
# Epoch 48/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 24.9183 - val_loss: 24.1915
# Epoch 49/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 19.5677 - val_loss: 31.6279
# Epoch 50/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 31.8507 - val_loss: 40.0914

# %%
lr
# Out:
# <Sequential name=sequential, built=True>

# %% [markdown]
# # Premier Exemple d'apprentissage

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.DataFrame([ {"n_chambres" : 2, "prix" : 10}, {"n_chambres" : 4, "prix" : 20}])
data
# Out:
#    n_chambres  prix
# 0           2    10
# 1           4    20

# %%
plt.scatter(data["n_chambres"], data['prix'], c="r")
plt.show()

# %% [markdown]
# prix = 5 * n_chambres

# %%
# y = 5 x

plt.scatter(data["n_chambres"], data['prix'], c="r")
plt.plot(data["n_chambres"], data['prix'])
plt.xlabel('Nombre de chambres')
plt.ylabel('Prix')
plt.show()

# %%
# entree  + instruction = sortie

# entree + sortie  == instruction ou les regles

# y= 5 x  model

# %%
data = pd.DataFrame([ {"n_chambres" : 2, "prix" : 10}, {"n_chambres" : 4, "prix" : 20},
                    {"n_chambres" : 3, "prix" : 15},
                     {"n_chambres" : 3, "prix" : 20},
                     {"n_chambres" : 1, "prix" : 3.5},
                    {"n_chambres" : 6, "prix" : 31},
                     {"n_chambres" : 5, "prix" : 33},
                    {"n_chambres" : 8, "prix" : 36},
                    {"n_chambres" : 7, "prix" : 50},
                    {"n_chambres" : 9, "prix" : 42},
                    ])
data
# Out:
#    n_chambres  prix
# 0           2  10.0
# 1           4  20.0
# 2           3  15.0
# 3           3  20.0
# 4           1   3.5
# 5           6  31.0
# 6           5  33.0
# 7           8  36.0
# 8           7  50.0
# 9           9  42.0

# %%
plt.scatter(data["n_chambres"], data['prix'], c="r")
plt.plot(data["n_chambres"], data['n_chambres'] * 5)
plt.xlabel('Nombre de chambres')
plt.ylabel('Prix')
plt.show()

# %%
x = n_chambres
y = Prix
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2445121141.py in <cell line: 0>()
# ----> 1 x = n_chambres
#       2 y = Prix
#
# NameError: name 'n_chambres' is not defined

# %%
def model(x, w):
  return w * x

# %%
model(x=3, w=5) # y= 5x
# Out:
# 15

# %%
# y= 6x
model(x=3, w=6)
# Out:
# 18

# %%
def erreur(x, w, y):
  y_model = model(x, w)

  distance = (y - y_model) **2

  return np.sum(distance)

# %%
x = 6, y = 54

# y = 5x, w = 5

# %%
erreur(x=6, w=5, y=54)
# Out:
# np.int64(576)

# %%
y_model = 5 * 6 = 30

distance = (54 - 30)**2
# Out:
#   File "/tmp/ipython-input-2617079781.py", line 1
#     y_model = 5 * 6 = 30
#               ^
# SyntaxError: cannot assign to expression

# %%
data['n_chambres'].values
# Out:
# array([2, 4, 3, 3, 1, 6, 5, 8, 7, 9])

# %%
n_chambres = data['n_chambres'].values
prix = data['prix'].values

# %%
erreur(x=n_chambres, w=5, y=prix) # y = 5 x
# Out:
# np.float64(342.25)

# %%
plt.scatter(data["n_chambres"], data['prix'], c="r")
plt.plot(data["n_chambres"], data['n_chambres'] * 5)
plt.plot(data["n_chambres"], data['n_chambres'] * 4)
plt.xlabel('Nombre de chambrees')
plt.ylabel('Prix')
plt.show()

# %%
erreur(x=n_chambres, w=4, y=prix)
# Out:
# np.float64(847.25)

# %%
plt.scatter(data["n_chambres"], data['prix'], c="r")
plt.plot(data["n_chambres"], data['n_chambres'] * 5, label='w=5')
plt.plot(data["n_chambres"], data['n_chambres'] * 4, label='w=4')
plt.plot(data["n_chambres"], data['n_chambres'] * 6, label='w=6')
plt.xlabel('Nombre de chambrees')
plt.ylabel('Prix')
plt.legend()
plt.show()

# %%
erreur(x=n_chambres, w=6, y=prix)
# Out:
# np.float64(425.25)

# %%
erreur(x=n_chambres, w=4.9, y=prix)
# Out:
# np.float64(366.2899999999999)

# %%
f"w = 5 : {erreur(x=n_chambres, w=5.1, y=prix)}", f"w = 5.1 : {erreur(x=n_chambres, w=5, y=prix)}"
# Out:
# ('w = 5 : 324.0900000000001', 'w = 5.1 : 342.25')

# %%
plt.scatter(data["n_chambres"], data['prix'], c="r")
plt.plot(data["n_chambres"], data['n_chambres'] * 5, c='c', label="w=5")
plt.plot(data["n_chambres"], data['n_chambres'] * 5.1, c='g', label="w=5.1")
plt.xlabel('Nombre de chambres')
plt.ylabel('Prix')
plt.legend()
plt.show()

# %%
erreur(x=n_chambres, w=5.2, y=prix) #y=5.2 x
# Out:
# np.float64(311.81000000000006)

# %%
erreur(x=n_chambres, w=5.3, y=prix)
# Out:
# np.float64(305.4099999999999)

# %%
erreur(x=n_chambres, w=5.4, y=prix) #y = 5.4x
# Out:
# np.float64(304.88999999999993)

# %%
erreur(x=n_chambres, w=5.5, y=prix)
# Out:
# np.float64(310.25)

# %%
erreur(x=n_chambres, w=5.6, y=prix)
# Out:
# np.float64(321.49)

# %%
plt.scatter(data["n_chambres"], data['prix'], c="r")
plt.plot(data["n_chambres"], data['n_chambres'] * 5, label='w=5')
plt.plot(data["n_chambres"], data['n_chambres'] * 5.4, label='w=5.4')

plt.xlabel('Nombre de chambrees')
plt.ylabel('Prix')
plt.legend()
plt.show()

# %%
possible_w = np.arange(-20, 20, 0.001)

# %%
possible_w
# Out:
# array([-20.   , -19.999, -19.998, ...,  19.997,  19.998,  19.999])

# %%
possible_w.size
# Out:
# 40000

# %%
errors = []

for d in possible_w:
  e = erreur(x=n_chambres, w=d, y=prix)
  errors.append(e)

# %%
plt.plot(possible_w, errors)
plt.xlabel('les w possible')
plt.ylabel('erreur')
plt.show()

# %%
np.array(errors).min()
# Out:
# np.float64(304.3920140000027)

# %%
np.argmin(errors)
# Out:
# np.int64(25359)

# %%
possible_w[25359]
# Out:
# np.float64(5.359000000030992)
